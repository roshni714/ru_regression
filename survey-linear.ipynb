# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("results/survey.csv")
df = df.sort_values("gamma")
loss = "poisson_nll"
model = "linear"
df = df[df.model_class == model]
df_cond = df[(df.method == "ru_regression") & (df.loss == loss) & (df.use_train_weights==False)]
df_cond_weights = df[(df.method == "ru_regression") & (df.loss == loss) & (df.use_train_weights==True)]
df_joint = df[(df.method == "joint_ru_regression") & (df.loss == loss)]
df
# Out:
#    dataset               method  gamma         loss  use_train_weights  \
# 12  survey        ru_regression    1.0  poisson_nll               True
# 4   survey  joint_ru_regression    1.0  poisson_nll              False
# 6   survey        ru_regression    1.0  poisson_nll              False
# 10  survey        ru_regression    1.5  poisson_nll               True
# 5   survey        ru_regression    1.5  poisson_nll              False
# 3   survey  joint_ru_regression    1.5  poisson_nll              False
# 2   survey  joint_ru_regression    2.0  poisson_nll              False
# 15  survey        ru_regression    2.0  poisson_nll               True
# 8   survey        ru_regression    2.0  poisson_nll              False
# 14  survey        ru_regression    2.5  poisson_nll               True
# 9   survey        ru_regression    2.5  poisson_nll              False
# 1   survey  joint_ru_regression    2.5  poisson_nll              False
# 0   survey  joint_ru_regression    3.0  poisson_nll              False
# 13  survey        ru_regression    3.0  poisson_nll               True
# 7   survey        ru_regression    3.0  poisson_nll              False
#
#    model_class  seed  test_ru_loss  test_ru_loss_se  test_loss  test_loss_se  \
# 12      linear     0      0.706452         0.002967   0.706452      0.002967
# 4       linear     0      0.739151         0.003036   0.739151      0.003036
# 6       linear     0      0.739151         0.003036   0.739151      0.003036
# 10      linear     0      0.944305         0.002135   0.542892      0.002260
# 5       linear     0      0.977796         0.002267   0.551320      0.002310
# 3       linear     0      0.861586         0.001815   0.563552      0.002329
# 2       linear     0      0.906345         0.001056   0.573375      0.001770
# 15      linear     0      1.014003         0.001507   0.562977      0.001753
# 8       linear     0      1.036867         0.001627   0.561785      0.001784
# 14      linear     0      1.032106         0.001023   0.642780      0.001319
# 9       linear     0      1.028777         0.001012   0.641024      0.001323
# 1       linear     0      0.936666         0.000539   0.669992      0.001227
# 0       linear     0      0.966995         0.000259   0.804328      0.000755
# 13      linear     0      1.009084         0.000543   0.745922      0.000921
# 7       linear     0      1.016695         0.000595   0.758282      0.000908
#
#     test_mse  test_mse_se  hps_ru_loss  hps_ru_loss_se    hps_mse  hps_mse_se  \
# 12  3.984465     0.008868    -0.593712        0.006375  10.778316    0.025853
# 4   4.336079     0.010108    -0.595002        0.006437  10.798530    0.025852
# 6   4.336079     0.010108    -0.595002        0.006437  10.798530    0.025852
# 10  2.661435     0.008345     0.305098        0.004029  11.684364    0.032521
# 5   2.739667     0.008423     0.301603        0.004134  11.629356    0.032312
# 3   2.827968     0.008751     0.332152        0.003787  11.612360    0.032298
# 2   2.635290     0.009639     0.715191        0.002389  12.933052    0.036990
# 15  2.589905     0.009586     0.688177        0.002718  12.938290    0.036972
# 8   2.597131     0.009497     0.684032        0.002809  12.889488    0.036824
# 14  2.847515     0.010882     0.869233        0.001827  14.046972    0.040219
# 9   2.846580     0.010847     0.865077        0.001822  14.051592    0.040233
# 1   2.932983     0.011165     0.891155        0.001436  14.258777    0.040825
# 0   3.321229     0.012379     0.967849        0.000798  15.324965    0.043646
# 13  3.164664     0.011938     0.953731        0.001093  14.973374    0.042714
# 7   3.195203     0.012008     0.951116        0.001138  15.015678    0.042828
#
#     hps_loss  hps_loss_se
# 12 -0.593712     0.006375
# 4  -0.595002     0.006437
# 6  -0.595002     0.006437
# 10 -0.424486     0.004920
# 5  -0.433796     0.004984
# 3  -0.431311     0.005031
# 2  -0.144454     0.003859
# 15 -0.153282     0.003821
# 8  -0.163063     0.003868
# 14  0.127564     0.002859
# 9   0.131807     0.002864
# 1   0.194304     0.002689
# 0   0.539033     0.001653
# 13  0.411544     0.001978
# 7   0.431933     0.001978

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
fontsize=15

labels = ["test_loss", "hps_loss"]
for i in range(2):
    ax[i].plot(df_cond_weights["gamma"], df_cond_weights[labels[i]], label="Weighted RU Regression", c="tab:blue", marker="o")
    ax[i].fill_between(df_cond_weights["gamma"], df_cond_weights[labels[i]]- df_cond_weights[labels[i] + "_se"], 
                       df_cond_weights[labels[i]] + df_cond_weights[labels[i] + "_se"], alpha=0.2, color="tab:blue")
    ax[i].plot(df_cond["gamma"], df_cond[labels[i]], label="RU Regression", c="tab:orange", marker="o")
    ax[i].fill_between(df_cond["gamma"], df_cond[labels[i]]- df_cond[labels[i] + "_se"], 
                       df_cond[labels[i]] + df_cond[labels[i] + "_se"], alpha=0.2, color="tab:orange")
    ax[i].plot(df_joint["gamma"], df_joint[labels[i]], label="Unconditional RU Regression", c="tab:green", marker="o")
    ax[i].fill_between(df_joint["gamma"], df_joint[labels[i]]- df_joint[labels[i] + "_se"], 
                       df_joint[labels[i]] + df_joint[labels[i] + "_se"], alpha=0.2, color="tab:green")
    

    
ax[1].set_ylabel("HPS Risk", fontsize=fontsize)
ax[1].set_title("HPS ($P$) Risk " + " vs. $\Gamma$", fontsize=fontsize)

# ax[2].set_ylabel("HPS RU Risk", fontsize=fontsize)
# ax[2].set_title("HPS ($P$) RU Risk " + " vs. $\Gamma$", fontsize=fontsize)

ax[0].set_ylabel("BRFSS Risk", fontsize=fontsize)
ax[0].set_title("BRFSS (Target $Q$) Risk " + " vs. $\Gamma$", fontsize=fontsize)

# ax[1].set_ylabel("BRFSS MSE" , fontsize=fontsize)
# ax[1].set_title("BRFSS (Target $Q$) MSE " + " vs. $\Gamma$" , fontsize=fontsize)

for i in range(len(ax)):
    ax[i].legend(fontsize=12)
    ax[i].set_xlabel("$\Gamma$", fontsize=fontsize)

plt.suptitle("Linear Decision Rule: HPS/BRFSS Mental Health Score Prediction", fontsize=fontsize)
plt.tight_layout()
plt.savefig("figs/survey_linear_res.pdf", bbox_inches="tight")
