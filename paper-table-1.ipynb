# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("results/sim_one_dim.csv")
df.groupby(["dataset", "method", "gamma", "p_train", "p_test"]).agg(["mean", "std"])["test_mse"].round(3)
# Out:
#                                                       mean    std
# dataset         method        gamma p_train p_test
# shifted_one_dim erm           1.0   0.1     0.1      6.306  0.187
#                                     0.2     0.1      6.939  0.174
#                                             0.2     10.480  0.126
#                                             0.5     20.866  0.305
#                                             0.7     27.880  0.484
#                                             0.9     34.913  0.668
#                                     0.5     0.5     15.743  0.152
#                                     0.7     0.7     13.341  0.123
#                                     0.9     0.9      6.274  0.176
#                 ru_regression 2.0   0.2     0.1     10.074  0.247
#                                             0.2     11.846  0.138
#                                             0.5     17.029  0.236
#                                             0.7     20.522  0.308
#                                             0.9     24.046  0.540
#                               4.0   0.2     0.1     12.456  0.431
#                                             0.2     13.388  0.309
#                                             0.5     16.093  0.179
#                                             0.7     17.898  0.300
#                                             0.9     19.750  0.584
#                               8.0   0.2     0.1     13.419  0.306
#                                             0.2     14.057  0.255
#                                             0.5     15.895  0.133
#                                             0.7     17.119  0.143
#                                             0.9     18.388  0.304
#                               16.0  0.2     0.1     13.613  0.400
#                                             0.2     14.197  0.308
#                                             0.5     15.873  0.140
#                                             0.7     16.983  0.262
#                                             0.9     18.142  0.480
