# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("results/sim_high_dim.csv")
df.groupby(["dataset", "method", "gamma", "p_train", "p_test"]).agg(["mean", "std"])["test_mse"].round(3)
# Out:
#                                                       mean    std
# dataset          method        gamma p_train p_test
# shifted_high_dim erm           1.0   0.1     0.1     0.025  0.000
#                                      0.2     0.1     0.028  0.000
#                                              0.2     0.043  0.000
#                                              0.5     0.088  0.002
#                                              0.7     0.118  0.002
#                                              0.9     0.148  0.003
#                                      0.5     0.5     0.066  0.000
#                                      0.7     0.7     0.056  0.000
#                                      0.9     0.9     0.025  0.000
#                  ru_regression 2.0   0.2     0.1     0.041  0.002
#                                              0.2     0.049  0.001
#                                              0.5     0.071  0.001
# ...
